# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 64.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.6/335.6 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 103.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 84.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 96.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 22.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.2/122.2 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.4/142.4 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.9/348.9 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 106.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.2/788.2 kB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.3/152.3 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 80.2 MB/s eta 0:00:00

# %%
from pathlib import Path
import os

BASE = Path('/content/drive/MyDrive/projects/enterprise-rag-ai-platform')
DATA_PLATFORM_BASE = Path('/content/drive/MyDrive/projects/modern-data-platform-blueprint')
WAREHOUSE_DB = DATA_PLATFORM_BASE / 'data' / 'warehouse' / 'warehouse.db'

os.chdir(BASE)
os.environ['WAREHOUSE_DB'] = str(WAREHOUSE_DB)

print('Warehouse DB exists:', WAREHOUSE_DB.exists())
print('Repo files:', os.listdir(BASE))
# Out:
# Warehouse DB exists: True
# Repo files: ['.DS_Store', 'src', 'data', 'app', 'docs', 'Enterprise_RAG_AI_Platform_Colab.ipynb', 'requirements.txt', 'README.md']

# %%
import os
os.environ['WAREHOUSE_DB'] = str(WAREHOUSE_DB)
print(os.environ['WAREHOUSE_DB'])
# Out:
# /content/drive/MyDrive/projects/modern-data-platform-blueprint/data/warehouse/warehouse.db

# %%
# !python -m src.build_sample_docs

# %%
# !python -m src.extract_sql_context
# !python -m src.build_index
# !python -m src.run_demo
# Out:
# Available tables: ['ai_customer_context', 'dim_customers', 'dim_dates', 'dim_products', 'fct_order_lines', 'mart_country_sales', 'mart_monthly_revenue', 'mart_top_customers', 'raw_transactions', 'stg_transactions']
# Extracted 4415 SQL records to /content/drive/MyDrive/projects/enterprise-rag-ai-platform/data/exports/sql_context.pkl
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 103/103 [00:00<00:00, 1142.31it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Batches: 100% 139/139 [01:59<00:00,  1.16it/s]
# Built FAISS index with 4420 records
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 103/103 [00:00<00:00, 1358.00it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ==========================================================================================
# Routing mode: hybrid
# Question: Which customers are high value and what support policy applies to them?
#
# Grounded answer:
# - [doc] support_excalation.txt: Support Escalation Guide Any customer with large open issues and lifetime revenue above $50,000 should be escalated to the customer success lead. Refund disputes above $2,500 should be reviewed by finance and support jointly. When a premium customer reports repeated shipment or billing issues, route the case to senior support within one business day. If multiple customers from the same country report delays, the regional operations manager should be notified.
# - [doc] support_escalation.txt: Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support.
# - [doc] loyalty_program.txt: Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews.
# - [sql] ai_customer_context: Customer 16808.0 is a low_value customer from United Kingdom. Lifetime value is 288.42 across 2 invoices. The last order timestamp was 2011-09-01 19:34:00. They purchased 21 distinct products.
# - [sql] ai_customer_context: Customer 16803.0 is a low_value customer from United Kingdom. Lifetime value is 332.30 across 1 invoices. The last order timestamp was 2011-10-05 14:28:00. They purchased 24 distinct products.
#
# Synthesis:
# Support Escalation Guide Any customer with large open issues and lifetime revenue above $50,000 should be escalated to the customer success lead. Refund disputes above $2,500 should be reviewed by finance and support jointly. When a premium customer reports repeated shipment or billing issues, route the case to senior support within one business day. If multiple customers from the same country report delays, the regional operations manager should be notified. Support Escalation Guide Any customer with lifetime revenue above $50,000 and repeated issues should be escalated to customer success. Refund disputes above $2,500 should be reviewed jointly by finance and support. Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews. Customer 16808.0 is a low_value customer from United Kingdom. Lifetime value is 288.42 across 2 invoices. The last order timestamp was 2011-09-01 19:34:00. They purchased 21 distinct products.
#
# ==========================================================================================
# Routing mode: doc
# Question: What does the loyalty program say about premium customers?
#
# Grounded answer:
# - [doc] loyalty_program.txt: Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews.
#
# Synthesis:
# Loyalty Program Customers are grouped into Standard, Growth, and Premium tiers based on annual revenue and purchase consistency. Premium customers receive priority support and proactive account reviews.
#
# ==========================================================================================
# Routing mode: hybrid
# Question: Which countries generate the most revenue?
#
# Grounded answer:
# - [sql] mart_country_sales: Country Switzerland generated 57089.90 in revenue across 54 invoices and 22 customers.
# - [sql] mart_country_sales: Country Netherlands generated 285446.34 in revenue across 95 invoices and 9 customers.
# - [sql] mart_country_sales: Country Saudi Arabia generated 145.92 in revenue across 1 invoices and 1 customers.
# - [sql] mart_country_sales: Country Brazil generated 1143.60 in revenue across 1 invoices and 1 customers.
# - [sql] mart_country_sales: Country Portugal generated 33747.10 in revenue across 58 invoices and 20 customers.
#
# Synthesis:
# Country Switzerland generated 57089.90 in revenue across 54 invoices and 22 customers. Country Netherlands generated 285446.34 in revenue across 95 invoices and 9 customers. Country Saudi Arabia generated 145.92 in revenue across 1 invoices and 1 customers. Country Brazil generated 1143.60 in revenue across 1 invoices and 1 customers.
#
# ==========================================================================================
# Routing mode: sql
# Question: Summarize the monthly revenue trend and the sales strategy.
#
# Grounded answer:
# - [sql] mart_monthly_revenue: In 2011-06, revenue was 761739.90 from 1576 invoices and 36056 order lines.
# - [sql] mart_monthly_revenue: In 2011-12, revenue was 638792.68 from 839 invoices and 25135 order lines.
# - [sql] mart_monthly_revenue: In 2011-02, revenue was 523631.89 from 1126 invoices and 27184 order lines.
# - [sql] mart_top_customers: Top customer 17841.0 from United Kingdom generated 40991.57 in revenue across 124 invoices. The last order timestamp was 2011-12-08 12:07:00.
# - [sql] mart_top_customers: Top customer 13089.0 from United Kingdom generated 58825.83 in revenue across 97 invoices. The last order timestamp was 2011-12-07 09:02:00.
#
# Synthesis:
# In 2011-06, revenue was 761739.90 from 1576 invoices and 36056 order lines. In 2011-12, revenue was 638792.68 from 839 invoices and 25135 order lines. In 2011-02, revenue was 523631.89 from 1126 invoices and 27184 order lines. Top customer 17841.0 from United Kingdom generated 40991.57 in revenue across 124 invoices. The last order timestamp was 2011-12-08 12:07:00.

# %%
# !ls data/exports
# !ls data/vectorstore
# Out:
# doc_chunks.pkl	sql_context.pkl
# faiss.index  metadata.pkl
